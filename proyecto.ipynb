# %%
import pandas as pd
# Out:
# C:\Users\Alumno\AppData\Local\Temp\ipykernel_3972\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.0

# %%
#carga los datos a la memoria ram 
spotify = pd.read_csv("spotify-2023.csv",encoding="latin-1")
#creamos un DF llamados spotify

# %%
#visualizar DF
spotify.head(10)#muestra los primeros registros
# Out:
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                             Columbia                     Quevedo
# 8                             fukumean                       Gunna
# 9                      La Bebe - Remix       Peso Pluma, Yng Lvcas
#
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# ...

# %%
spotify.tail(10)#muestra los ultimos 10 registros
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 943         Privileged Rappers    Drake, 21 Savage             2
# 944              The Astronaut                 Jin             1
# 945            BackOutsideBoyz               Drake             1
# 946                 Broke Boys    Drake, 21 Savage             2
# 947              The Great War        Taylor Swift             1
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 943           2022              11             4                  1007
# 944           2022              10            28                   481
# ...

# %%
spotify.sample(5)#muestra 5 registros aleatorios
# Out:
#                                             track_name  \
# 208  Self Love (Spider-Man: Across the Spider-Verse...
# 842                                    Love Of My Life
# 200  Annihilate (Spider-Man: Across the Spider-Vers...
# 318                                   Malas Decisiones
# 685                                  Thinking Out Loud
#
#                                 artist(s)_name  artist_count  released_year  \
# 208                    Metro Boomin, Coi Leray             2           2023
# 842                               Harry Styles             1           2022
# 200  Swae Lee, Lil Wayne, Offset, Metro Boomin             4           2023
# 318                                   Kenia OS             1           2022
# 685                                 Ed Sheeran             1           2014
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 208               6             2                   332                  5
# ...

# %%
#visualizar caracteristicas generales de DF
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
spotify.shape #(filas y Columnas)
# Out:
# (953, 24)

# %%
spotify.shape[0]#devuelve no. de fila
# Out:
# 953

# %%
spotify.shape[1] #devuelve no. de columnas
# Out:
# 24

# %%
spotify.index#devuelve el indice inicial,indice final y incremento rntre inndices
# Out:
# RangeIndex(start=0, stop=953, step=1)

# %%
spotify.dtypes
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %%
spotify.dtypes[5:9]
# Out:
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# dtype: object

# %%
spotify.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
spotify[spotify['released_day'] ==1930]
# Out:
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts, in_deezer_playlists, in_deezer_charts, in_shazam_charts, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%]
# Index: []
#
# [0 rows x 24 columns]

# %%
spotify["artist(s)_name"]
# Out:
# 0        Latto, Jung Kook
# 1             Myke Towers
# 2          Olivia Rodrigo
# 3            Taylor Swift
# 4               Bad Bunny
#               ...
# 948          Selena Gomez
# 949          Taylor Swift
# 950    Feid, Paulo Londra
# 951    Feid, Sech, Jhayco
# 952             Burna Boy
# Name: artist(s)_name, Length: 953, dtype: object

# %%
spotify[["artist(s)_name","streams","mode"]]
# Out:
#          artist(s)_name    streams   mode
# 0      Latto, Jung Kook  141381703  Major
# 1           Myke Towers  133716286  Major
# 2        Olivia Rodrigo  140003974  Major
# 3          Taylor Swift  800840817  Major
# 4             Bad Bunny  303236322  Minor
# ..                  ...        ...    ...
# 948        Selena Gomez   91473363  Major
# 949        Taylor Swift  121871870  Major
# 950  Feid, Paulo Londra   73513683  Major
# 951  Feid, Sech, Jhayco  133895612  Major
# 952           Burna Boy   96007391  Minor
#
# [953 rows x 3 columns]

# %%
spotify[spotify["released_year"]<1930]
# Out:
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts, in_deezer_playlists, in_deezer_charts, in_shazam_charts, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%]
# Index: []
#
# [0 rows x 24 columns]

# %%
spotify[spotify["released_year"]<=1930]
# Out:
#           track_name           artist(s)_name  artist_count  released_year  \
# 439  Agudo Mï¿½ï¿½gi  Styrx, utku INC, Thezth             3           1930
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 439               1             1                   323                  0
#
#       streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 439  90598517                   4  ...  130  F#  Minor             65
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 439         49       80             22                   4           7
#
#      speechiness_%
# 439              5
#
# [1 rows x 24 columns]

# %%
spotify[spotify["released_year"]<=2000]
# Out:
#                                             track_name  \
# 65                                              Yellow
# 80                                             Riptide
# 114                  Everybody Wants To Rule The World
# 166            Every Breath You Take - Remastered 2003
# 182                                              Creep
# 195                       Have You Ever Seen The Rain?
# 199                                         Take On Me
# 250                                The Real Slim Shady
# 265  Cupid ï¿½ï¿½ï¿½ Twin Ver. (FIFTY FIFTY) ï¿½ï¿½...
# 320                                 Gangsta's Paradise
# 358                                         In The End
# 424             Running Up That Hill (A Deal With God)
# 425                                           Dream On
# 439                                    Agudo Mï¿½ï¿½gi
# 441                    All I Want for Christmas Is You
# 442                                     Last Christmas
# ...

# %%
spotify[spotify["released_year"]<=2000].sort_values(by="released_year",ascending=True)
# Out:
#                                             track_name  \
# 439                                    Agudo Mï¿½ï¿½gi
# 469                                    White Christmas
# 460  The Christmas Song (Merry Christmas To You) - ...
# 466             Let It Snow! Let It Snow! Let It Snow!
# 459           A Holly Jolly Christmas - Single Version
# 444                                   Jingle Bell Rock
# 496                     Jingle Bells - Remastered 1999
# 443                  Rockin' Around The Christmas Tree
# 495                   Run Rudolph Run - Single Version
# 476  It's Beginning to Look a Lot Like Christmas (w...
# 448             Let It Snow! Let It Snow! Let It Snow!
# 483                    Deck The Hall - Remastered 1999
# 447           It's the Most Wonderful Time of the Year
# 471                  Christmas (Baby Please Come Home)
# 454                                        Sleigh Ride
# 195                       Have You Ever Seen The Rain?
# ...

# %%
spotify[(spotify["released_year"]>=2005)&(spotify["released_year"]<=2009)].sort_values(by="released_year",ascending=True)
# Out:
#                                             track_name  \
# 491  You Make It Feel Like Christmas (feat. Blake S...
# 134                                                505
# 75                                        Viva La Vida
# 893                                          Heartless
#
#                   artist(s)_name  artist_count  released_year  released_month  \
# 491  Gwen Stefani, Blake Shelton             2           2005               9
# 134               Arctic Monkeys             1           2007               4
# 75                      Coldplay             1           2008               1
# 893                   Kanye West             1           2008               1
#
#      released_day  in_spotify_playlists  in_spotify_charts     streams  \
# 491            20                  2577                  0   180577478
# 134            20                 13985                 25  1217120710
# 75              1                 33898                 62  1592909789
# ...

# %%
spotify[spotify["artist(s)_name"]=="Natanael Cano"]
# Out:
#          track_name artist(s)_name  artist_count  released_year  \
# 150  Mi Bello Angel  Natanael Cano             1           2023
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 150               6            30                    86                  8
#
#       streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 150  31873544                   7  ...  128   A  Minor             81
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 150         90       77              1                   0           9
#
#      speechiness_%
# 150              5
#
# [1 rows x 24 columns]

# %%
spotify[spotify["artist(s)_name"]=="Fuerza Regida"].sort_values(by="released_year",ascending=True)
# Out:
#      track_name artist(s)_name  artist_count  released_year  released_month  \
# 25  SABOR FRESA  Fuerza Regida             1           2023               6
# 39          TQM  Fuerza Regida             1           2023               5
#
#     released_day  in_spotify_playlists  in_spotify_charts    streams  \
# 25            22                   250                 26   78300654
# 39            19                   584                 28  176553476
#
#     in_apple_playlists  ...  bpm key   mode danceability_%  valence_%  \
# 25                  16  ...  130   G  Minor             79         96
# 39                  16  ...  125   F  Minor             79         96
#
#    energy_% acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 25       86              9                   0           9              9
# 39       85             27                   0          11              6
#
# [2 rows x 24 columns]

# %%
spotify[spotify["artist(s)_name"]=="Peso Pluma"].sort_values(by="released_year",ascending=True)
# Out:
#          track_name artist(s)_name  artist_count  released_year  \
# 124  Por las Noches     Peso Pluma             1           2021
# 151             Bye     Peso Pluma             1           2023
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 124               6            11                   457                 24
# 151               5            26                   324                 14
#
#        streams  in_apple_playlists  ...  bpm  key   mode danceability_%  \
# 124  330346424                   8  ...   92  NaN  Major             81
# 151   95053634                  13  ...  122  NaN  Major             78
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 124         39       60             31                   0           7
# 151         70       81             57                   0          10
#
#      speechiness_%
# 124              3
# 151              5
#
# [2 rows x 24 columns]

# %%
spotify["artist(s)_name"].unique()
# Out:
# array(['Latto, Jung Kook', 'Myke Towers', 'Olivia Rodrigo',
#        'Taylor Swift', 'Bad Bunny', 'Dave, Central Cee',
#        'Eslabon Armado, Peso Pluma', 'Quevedo', 'Gunna',
#        'Peso Pluma, Yng Lvcas', 'Bad Bunny, Grupo Frontera', 'NewJeans',
#        'Miley Cyrus', 'David Kushner', 'Harry Styles', 'SZA',
#        'Fifty Fifty', 'Billie Eilish', 'Feid, Young Miko', 'Jimin',
#        'Gabito Ballesteros, Junior H, Peso Pluma', 'Arctic Monkeys',
#        'Bizarrap, Peso Pluma', 'The Weeknd, Madonna, Playboi Carti',
#        'Fuerza Regida', 'Rï¿½ï¿½ma, Selena G', 'Tainy, Bad Bunny',
#        'Morgan Wallen', 'Dua Lipa', 'Troye Sivan',
#        'Peso Pluma, Grupo Frontera',
#        'The Weeknd, 21 Savage, Metro Boomin', 'Karol G, Shakira',
#        'Big One, Duki, Lit Killah, Maria Becerra, FMK, Rusherking, Emilia, Tiago pzk',
#        'Yahritza Y Su Esencia, Grupo Frontera', 'Junior H, Peso Pluma',
#        'Post Malone, Swae Lee', 'Bebe Rexha, David Guetta',
# ...

# %%
spotify[(spotify["artist(s)_name"]=="Natanael Cano")|(spotify["artist(s)_name"]=="Myke Towers")|(spotify["artist(s)_name"]=="Peso Pluma")|(spotify["artist(s)_name"]=="Drake")|(spotify["artist(s)_name"]=="Fuerza Regida")].sort_values(by="released_year",ascending=True)
# Out:
#           track_name artist(s)_name  artist_count  released_year  \
# 124   Por las Noches     Peso Pluma             1           2021
# 865          Massive          Drake             1           2022
# 874           Sticky          Drake             1           2022
# 945  BackOutsideBoyz          Drake             1           2022
# 1               LALA    Myke Towers             1           2023
# 25       SABOR FRESA  Fuerza Regida             1           2023
# 39               TQM  Fuerza Regida             1           2023
# 150   Mi Bello Angel  Natanael Cano             1           2023
# 151              Bye     Peso Pluma             1           2023
# 235  Search & Rescue          Drake             1           2023
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 124               6            11                   457                 24
# 865               6            17                  5263                  0
# ...

# %%
mi_playlist=spotify[(spotify["artist(s)_name"]=="Natanael Cano")|(spotify["artist(s)_name"]=="Myke Towers")|(spotify["artist(s)_name"]=="Peso Pluma")|(spotify["artist(s)_name"]=="Drake")|(spotify["artist(s)_name"]=="Fuerza Regida")].sort_values(by="released_year",ascending=True)

# %%
mi_playlist.to_csv("playlist.csv",index=False)
